# %% [markdown]
# # Example File
#
# This file is meant to show how a typical manim file is laid out.

# %%
from manim import *

class Test(Scene):
    def construct(self):
        circle = Circle()
        self.play(Create(circle))
        self.wait()
